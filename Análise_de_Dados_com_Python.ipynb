# %% [markdown]
# Passo a Passo de solução do Desafio

# %%
# Lógica de Programação

# Passo 1 - Percorrer todos os arquivos da pasta base de dados (Pasta vendas)

import os
import pandas as pd



lista_arquivos = os.listdir("/content/drive/MyDrive/Vendas")
display(lista_arquivos)

tabela_total = pd.DataFrame()
# Passo 2 - Importar a base de Dados de vendas

for arquivos in lista_arquivos:

  if "Vendas" in arquivos:
    tabela = pd.read_csv(f"/content/drive/MyDrive/Vendas/{arquivos}")
    print(arquivos)
    display(tabela)
    tabela_total = tabela_total.append(tabela)

# %%
# Passo 3 - Tratar / Compilar as base de dados
display(tabela_total)
# Out:
#      Unnamed: 0     SKU    Produto  Quantidade Vendida Primeiro Nome  \
# 0            17  HL4379  Televisão                   2      Carolina
# 1            25  HL4379  Televisão                   1        Danilo
# 2            27  HL1918     iPhone                   5       Bernard
# 3            54  HL1918     iPhone                   5         Lucas
# 4            67  HL8851   Notebook                   5      Bernardo
# ..          ...     ...        ...                 ...           ...
# 699        9947  HL1918     iPhone                   2     Gabrielle
# 700        9980  HL1918     iPhone                   5          João
# 701        9983  HL2714     Tablet                   5        Bianca
# 702        9993  HL1148     Câmera                   4        Victor
# 703        9997  HL1918     iPhone                   4        Norman
#
#        Sobrenome        Data            Loja  Preco Unitario  Unnamed: 8
# ...

# %%
# Passo 4 - Calcular o produto mais vendido (em  quantidades)
tabela_produtos = tabela_total.groupby('Produto').sum()
tabela_produtos = tabela_produtos [["Quantidade Vendida", "Preco Unitario"]].sort_values(by="Quantidade Vendida", ascending=False)
display(tabela_produtos)
# Out:
#             Quantidade Vendida  Preco Unitario
# Produto
# iPhone                    8974        15778100
# Televisão                 5931         4905000
# Notebook                  3249         3717000
# Android                   3183         3631200
# SmartWatch                2980         1393000
# Tablet                    2921         1556800
# Câmera                    2805         2020200

# %%
# Passo 5 - Cacular o Produto que mais faturou (em Faturamento)
tabela_total['Faturamento'] = tabela_total["Quantidade Vendida"] * tabela_total["Preco Unitario"]
tabela_faturamento = tabela_total.groupby('Produto').sum()
display(tabela_faturamento)
# Out:
#             Unnamed: 0  Quantidade Vendida  Preco Unitario  Unnamed: 8  \
# Produto
# Android        5164013                3183         3631200         0.0
# Câmera         4848296                2805         2020200         0.0
# Notebook       5393100                3249         3717000         0.0
# SmartWatch     4968367                2980         1393000         0.0
# Tablet         4920118                2921         1556800         0.0
# Televisão      9675708                5931         4905000         0.0
# iPhone        15015399                8974        15778100         0.0
#
#             Faturamento
# Produto
# Android        10822200
# Câmera          5890500
# Notebook       11371500
# SmartWatch      4172000
# Tablet          4673600
# Televisão      14827500
# iPhone         47562200

# %%
# Passo 6 - Calcular a loja/cidade que mais vendeu (em Faturamento) - Criar um gráfico/Dashboard 
tabela_lojas = tabela_total.groupby('Loja').sum()
tabela_lojas = tabela_lojas[['Quantidade Vendida', 'Preco Unitario', 'Faturamento']].sort_values(by= 'Faturamento', ascending= False)
display(tabela_lojas)
# Out:
#                 Quantidade Vendida  Preco Unitario  Faturamento
# Loja
# São Paulo                     6674         7340600     22098300
# Rio de Janeiro                4393         4970300     14867800
# Fortaleza                     4320         4719600     14087900
# Salvador                      4027         4345900     13111300
# Goiás                         2242         2421700      7441800
# Recife                        2208         2410500      7303000
# Curitiba                      2151         2337200      7060500
# Porto Alegre                  2103         2305300      6868600
# Belo Horizonte                1925         2150200      6480300

# %%
import plotly.express as px
grafico = px.bar(tabela_lojas, x = tabela_lojas.index, y = 'Faturamento')
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
